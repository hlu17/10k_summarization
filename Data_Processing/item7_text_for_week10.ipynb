# %% [markdown]
# ## In this notebook, we joined each report's processed Item 7 text with their respective summary labels, in preparation for model training.

# %%
# mount Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import packages
import pandas as pd
import numpy as np
import json
import glob
import os.path
import re
#import openai
from tqdm import tqdm

# %%
# load processed data in HTML format, where all tables are identified
file_path = "/content/drive/MyDrive/w210_capstone_project/data/SEC_Edgar_Annual_Financial_Filings_2021/working2/"

file_list = glob.glob(os.path.join(file_path,'*.htm'))

# get file and label indices for join
def get_indices(path, kind):
  if kind == "report":
    x = re.sub("/content/drive/MyDrive/w210_capstone_project/data/SEC_Edgar_Annual_Financial_Filings_2021/working2/", "", path)
  elif kind == "label":
    x = re.sub("/content/drive/MyDrive/w210_capstone_project/data/SEC_Edgar_Annual_Financial_Filings_2021/summaries/", "", path)
  x = x.split("_")[0]
  return x

reports = []
for file in file_list:
  index = get_indices(file, "report")
  with open(file, 'r') as html_file:
    text = "\n".join(html_file.readlines())
    reports.append((index, text))

len(reports)
# Out:
# 191

# %%
# get labels
label_path = "/content/drive/MyDrive/w210_capstone_project/data/SEC_Edgar_Annual_Financial_Filings_2021/summaries/"

label_list = glob.glob(os.path.join(label_path,'*'))

labels = [get_indices(l, "label") for l in label_list]
len(labels)

label_texts = [] 

for label in label_list:
  index = get_indices(label, "label")
  with open(label, 'r') as file:
    text = file.read()
    label_texts.append((index, text))

len(label_texts)
# Out:
# 50

# %%
def item7_text_only(text):
  # remove tables identified earlier
  tmp = re.sub('<openai>[ 0-9]+<\/openai>', ' ', text)
  # keep only item 7
  tmp = re.sub("<div id='Item 7A'>[\S\s]+<\/div>", ' ', tmp)
  # break HTML by ending HTML tag i.e. </xxx>
  tmp = re.split('<\/[A-Za-z]+>', str(tmp))
  # replace starting HTML tag i.e. <xxx>
  tmp = [re.sub('<[^\<\>]+>', ' ', t) for t in tmp]
  # concat back into one string
  return re.sub('\s+',' ', ' '.join(tmp)).strip()

# %%
def cleanse(text):
  x = re.sub('\n', ' ', text)
  return x

# %%
cleaned_reports = [{'id': r[0], 'report': item7_text_only(r[1])} for r in reports]
# cleaned_reports = sorted(cleaned_reports, key = lambda x: len(x[1])*-1)
cleaned_labels = [{'id': l[0], 'label': cleanse(l[1])} for l in label_texts]

# %%
report_df = []
for i in cleaned_reports:
  report_df.append({"id":i['id'], "report_length": len(i['report'].split(" ")), "report": i['report'], "has_label": i['id'] in labels})
report_df = pd.DataFrame(report_df)
report_df.head()
# Out:
#         id  report_length                                             report  \
# 0  1001601           4617  Overview Following a review of its Bitcoin min...
# 1  1002517          12011  The following Management’s Discussion and Anal...
# 2  1013462          10884  Business Ansys, a Delaware corporation formed ...
# 3  1013857           4251  BUSINESS OVERVIEW We develop, market, license,...
# 4  1015739              1
#
#    has_label
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False

# %%
label_df = []
for i in cleaned_labels:
  label_df.append({"id":i['id'], "label_length": len(i['label'].split(" ")), "label": i['label']})
label_df = pd.DataFrame(label_df)
label_df.head()
# Out:
#        id  label_length                                              label
# 0    8670          1142  AUTOMATIC DATA PROCESSING, INC. (“ADPI”)  Auto...
# 1   50471           907  Park City Group, Inc. (“PCGI”) The Company is ...
# 2   78749           756  AGILYSYS, Inc. (“AI”) Agilysys has been a lead...
# 3  317788           927  Digital Turbine, Inc. (“DTI”) Digital Turbine,...
# 4  320340           933  Intelligent Systems Corporation (“ISC”)  ISC’s...

# %%
df = pd.merge(label_df, report_df, how = 'left', on = 'id')
df.head(50)
# Out:
#          id  label_length                                              label  \
# 0      8670          1142  AUTOMATIC DATA PROCESSING, INC. (“ADPI”)  Auto...
# 1     50471           907  Park City Group, Inc. (“PCGI”) The Company is ...
# 2     78749           756  AGILYSYS, Inc. (“AI”) Agilysys has been a lead...
# 3    317788           927  Digital Turbine, Inc. (“DTI”) Digital Turbine,...
# 4    320340           933  Intelligent Systems Corporation (“ISC”)  ISC’s...
# 5    713425           880  American Software, Inc.. (“ASI”)  ASI operates...
# 6    723531           670  Paychex, Inc. (“PI”)  PI is a leading human re...
# 7   1810806          1471  Unity is the world’s leading platform for crea...
# 8   1806837           868  Vertex is a leading provider of enterprise tax...
# 9   1794515          1292  ZoomInfo is a leading go-to-market intelligenc...
# 10  1803696          1676  On December 18, 2019, Xperi Corporation (“Xper...
# 11  1786352          1232  The company is a leading provider of cloud-bas...
# 12  1773383          1433  The company offers the market-leading software...
# 13  1768267          1275  Cerence builds AI powered virtual assistants f...
# 14  1764925          1911  ¬Slack is a new layer of the business technolo...
# 15  1739942          1534  SolarWinds is a leading provider of informatio...
# 16  1739936          1562  The company was founded in 1999 and is a leade...
# 17   736012          1076  The company develops, sells and supports produ...
# 18   746210           929  Since the closing of the Merger on October 1, ...
# 19   769397          1065  Autodesk makes software for people who make th...
# 20   789019          1094  Microsoft is a technology company whose missio...
# 21   796343          1195  Subsequent to November 27, 2020, the company c...
# 22   807863          1186  Mitek is a leading innovator of mobile image c...
# 23   807882          1447  As of October 3, 2021, the company operated an...
# 24   813672          1632  The company enables its customers to develop e...
# 25   814547          2158  In fiscal 2021, the company’s B2B scoring solu...
# 26   814549          1826  Ebix endeavors to provide on-demand software a...
# 27   816761          1031  Teradata Corporation is a leading multi-cloud ...
# 28   823546          1434  On June 27, 2018, RocketFuel Blockchain Compan...
# 29   827876           926  The company earned $49,438,115 in revenues dur...
# 30  1725579          1497  The company is a leading technology workforce ...
# 31   829323          1855  Inuvo is a technology company that develops an...
# 32   843006           628  Total revenue increased by $2,231,000, or 14%,...
# 33   849399          2135  NortonLifeLock Inc. has the largest Consumer C...
# 34   727634           787  iSign Solutions Inc. (“III”)  The Company is a...
# 35   855612          1356  The company is a leader in providing cloud ema...
# 36   860731          2230  The company provides integrated information ma...
# 37   876167          2012  Progress Software Corporation provides product...
# 38   877890          1587  Citrix is an enterprise software company focus...
# 39   883241          1305  Synopsys, Inc. provides products and services ...
# 40   884144          1434  The company is a leading provider of cloud-bas...
# 41   892482          1322  The company generates revenue through the sale...
# 42   922521          1752  FalconStor is a data protection leader that en...
# 43   929940          1489  The company is a global leader in asset optimi...
# 44   935036          1929  ACI Worldwide powers digital payments for more...
# 45   941685          2123  The company is a pioneer and leader in biometr...
# 46   948708           543  Providing software solutions that simplify and...
# 47  1001601          1920  Following a review of its Bitcoin mining opera...
# 48  1002517          1995  Overview Business Overview The company is a pi...
# 49  1013462          1256  Business Ansys, a Delaware corporation formed ...
#
#     report_length                                             report  \
# 0            7231  Tabular dollars are presented in millions, exc...
# 1            3859  The following Management’s Discussion and Anal...
# 2            5664  In “Management’s Discussion and Analysis of Fi...
# 3           12886  The following discussion should be read in con...
# 4            3481  Executive Summary Our consolidated operations ...
# 5            6742  The following discussion and analysis should b...
# 6            6794  20 Fiscal 2021 Business Highlights Highlights ...
# 7            8898  Please read the following discussion and analy...
# 8           14093  comprise 72.5% of our 2020 software subscripti...
# 9           17675  The following discussion and analysis of our f...
# 10          12509  The following discussion (presented in thousan...
# 11           9861  You should read the following discussion and a...
# 12           9128  The following discussion and analysis of our f...
# 13          14492  Management’s Discussion and Analysis of Financ...
# 14          10361  You should read the following discussion and a...
# 15          12401  The following discussion and analysis of our f...
# 16           7734  The following discussion and analysis of our f...
# 17           3048  Our Business We develop, sell and support prod...
# 18           4762  The following discussion should be read in con...
# 19          10542  The following discussion and analysis of our f...
# 20            439  The following Management’s Discussion and Anal...
# 21           8232  The following discussion should be read in con...
# 22          10350  You should read this discussion together with ...
# 23           5128  GENERAL For an understanding of the significan...
# 24           6765  The following discussion should be read in con...
# 25          10527  Our Management’s Discussion and Analysis of Fi...
# 26           5744  As used herein, the terms “Ebix,” “the Company...
# 27           7356  You should read the following discussion in co...
# 28           2596  Overview Our Corporate History On June 27, 201...
# 29           4425  Forward-Looking Statements The following discu...
# 30           8919  The following discussion and analysis of our f...
# 31           4124  The following discussion of our financial cond...
# 32              1
# 33           6325  Please read the following discussion and analy...
# 34           5073  The following discussion and analysis should b...
# 35           7443  The following discussion and analysis contains...
# 36          10098  The following discussion and analysis should b...
# 37           8739  Forward-Looking Statements Certain statements ...
# 38          10427  Our operating results and financial condition ...
# 39           6279  Overview The following overview of our financi...
# 40           7975  CAUTIONARY STATEMENT REGARDING FORWARD-LOOKING...
# 41           6508  The following discussion and analysis of our f...
# 42           7237  The following Management’s Discussion and Anal...
# 43           8797  You should read the following discussion in co...
# 44          10090  Overview ACI Worldwide powers digital payments...
# 45          10593  The following discussion should be read in con...
# 46           4206  The following discussion of our financial cond...
# 47           4617  Overview Following a review of its Bitcoin min...
# 48          12011  The following Management’s Discussion and Anal...
# 49          10884  Business Ansys, a Delaware corporation formed ...
#
#     has_label
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
# 30       True
# 31       True
# 32       True
# 33       True
# 34       True
# 35       True
# 36       True
# 37       True
# 38       True
# 39       True
# 40       True
# 41       True
# 42       True
# 43       True
# 44       True
# 45       True
# 46       True
# 47       True
# 48       True
# 49       True

# %%
df.to_pickle(os.path.join(file_path, "item7_text3.pkl"))

# %%
df[["id", "report_length", "label_length"]][(df["has_label"] == True) & (df['report_length'] <= df['label_length'])]
# Out:
#         id  report_length  label_length
# 20  789019            439          1094
# 32  843006              1           628
